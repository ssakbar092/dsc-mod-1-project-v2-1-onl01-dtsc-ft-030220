# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name: Saeed Akbar(Zedd)
# * Student pace: Full time[03/02/2020]
# * Scheduled project review date/time: 04/02/2020
# * Instructor name: Amber Yandow
# * Blog post URL: " https://lifeofdataminers.wordpress.com/2020/04/01/a-journey-of-a-data-scientist/ "

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Movie Info Dataset

# %%
cd
# Out:
# C:\Users\ssakb

# %%
cd zippedData/
# Out:
# C:\Users\ssakb\zippedData

# %%
df=pd.read_csv("rt.movie_info.tsv.gz", sep='\t')
df
# Out:
#         id                                           synopsis rating  \
# 0        1  This gritty, fast-paced, and innovative police...      R
# 1        3  New York City, not-too-distant-future: Eric Pa...      R
# 2        5  Illeana Douglas delivers a superb performance ...      R
# 3        6  Michael Douglas runs afoul of a treacherous su...      R
# 4        7                                                NaN     NR
# ...    ...                                                ...    ...
# 1555  1996  Forget terrorists or hijackers -- there's a ha...      R
# 1556  1997  The popular Saturday Night Live sketch was exp...     PG
# 1557  1998  Based on a novel by Richard Powell, when the l...      G
# 1558  1999  The Sandlot is a coming-of-age story about a g...     PG
# 1559  2000  Suspended from the force, Paris cop Hubert is ...      R
#
#                                                   genre            director  \
# ...

# %%
print(df.isnull().sum())
print(df.info())
# Out:
# id                 0
# synopsis          62
# rating             3
# genre              8
# director         199
# writer           449
# theater_date     359
# dvd_date         359
# currency        1220
# box_office      1220
# runtime           30
# studio          1066
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1560 entries, 0 to 1559
# Data columns (total 12 columns):
# id              1560 non-null int64
# synopsis        1498 non-null object
# rating          1557 non-null object
# genre           1552 non-null object
# director        1361 non-null object
# writer          1111 non-null object
# theater_date    1201 non-null object
# dvd_date        1201 non-null object
# currency        340 non-null object
# box_office      340 non-null object
# runtime         1530 non-null object
# studio          494 non-null object
# dtypes: int64(1), object(11)
# memory usage: 146.4+ KB
# None

# %%
#Dropping all the null values in the dataset and arranginf the box office values in descending order
df=df.dropna().dropna(axis=1)
df=df.sort_values("box_office",ascending=False)
df
# Out:
#         id                                           synopsis rating  \
# 1510  1944  In the 3D action-comedy The Green Hornet, Brit...  PG-13
# 1469  1890  A misplaced sausage and his savory friends emb...      R
# 816   1055  The grim futility of the war between Bosnia an...      R
# 1016  1317  For an awkward, self-conscious girl like Kiki,...  PG-13
# 1464  1884  What do you get when you mix fearless comedic ...  PG-13
# ...    ...                                                ...    ...
# 390    505  Premiering to rave reviews at the 2013 Sundanc...      R
# 1215  1567  Lust is in the air on Harford Road and Sylvia ...   NC17
# 1213  1564  Real-life sweethearts Michael Cera and Charlyn...  PG-13
# 15      22  Two-time Academy Award Winner Kevin Spacey giv...      R
# 86     108  A picture-perfect family moves into an upscale...      R
#
#                                                   genre  \
# 1510  Action and Adventure|Comedy|Science Fiction an...
# ...

# %%
#Removing ',' from the integer value and removing '$' incase if it is placed in the box office values
df['box_office']= df['box_office'].apply(lambda x: x.replace('$', '').replace(',', '')).astype('int64')
df
# Out:
#         id                                           synopsis rating  \
# 1510  1944  In the 3D action-comedy The Green Hornet, Brit...  PG-13
# 1469  1890  A misplaced sausage and his savory friends emb...      R
# 816   1055  The grim futility of the war between Bosnia an...      R
# 1016  1317  For an awkward, self-conscious girl like Kiki,...  PG-13
# 1464  1884  What do you get when you mix fearless comedic ...  PG-13
# ...    ...                                                ...    ...
# 390    505  Premiering to rave reviews at the 2013 Sundanc...      R
# 1215  1567  Lust is in the air on Harford Road and Sylvia ...   NC17
# 1213  1564  Real-life sweethearts Michael Cera and Charlyn...  PG-13
# 15      22  Two-time Academy Award Winner Kevin Spacey giv...      R
# 86     108  A picture-perfect family moves into an upscale...      R
#
#                                                   genre  \
# 1510  Action and Adventure|Comedy|Science Fiction an...
# ...

# %%
#Sorting the values for the first 100 to project a graph
# Dropping unncessary columns 
df = df.sort_values(["box_office"],ascending=False).head(100)
df.drop(["id","dvd_date","currency"],axis=1,inplace=True)
df
print(df.columns)
print(df.isnull().sum())
print(df.info())
# Out:
# Index(['synopsis', 'rating', 'genre', 'director', 'writer', 'theater_date',
#        'box_office', 'runtime', 'studio'],
#       dtype='object')
# synopsis        0
# rating          0
# genre           0
# director        0
# writer          0
# theater_date    0
# box_office      0
# runtime         0
# studio          0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 827 to 633
# Data columns (total 9 columns):
# synopsis        100 non-null object
# rating          100 non-null object
# genre           100 non-null object
# director        100 non-null object
# writer          100 non-null object
# theater_date    100 non-null object
# box_office      100 non-null int64
# runtime         100 non-null object
# studio          100 non-null object
# dtypes: int64(1), object(8)
# memory usage: 7.8+ KB
# None

# %%
#Rearranging the columns for better output
#Applying titling format to all the Columns Title
df=df[['director','writer','genre','rating','theater_date','box_office','runtime','studio','synopsis']]
df.columns = map(str.title, df.columns)
df
# Out:
#                                    Director  \
# 827                              Mel Gibson
# 877                           Peter Jackson
# 1188                             Sam Mendes
# 690                               Jay Roach
# 1117                         Chris Columbus
# ...                                     ...
# 1275                        David Mackenzie
# 450                         Justin Chadwick
# 247                      Guillermo del Toro
# 1541                            Joss Whedon
# 633   Anthony Bell|Ben Gluck|Benjamin Gluck
#
#                                                  Writer  \
# 827                      Mel Gibson|Benedict Fitzgerald
# 877   Peter Jackson|Philippa Boyens|Guillermo del To...
# 1188                 John Logan|Robert Wade|Neal Purvis
# 690                           Jim Herzfeld|John Hamburg
# 1117                                       Steve Kloves
# ...                                                 ...
# ...

# %%
#Dropping the anonymous index value and resetting the index value
df=df.reset_index()
df= df.drop('index',axis=1)
df
# Out:
#                                  Director  \
# 0                              Mel Gibson
# 1                           Peter Jackson
# 2                              Sam Mendes
# 3                               Jay Roach
# 4                          Chris Columbus
# ..                                    ...
# 95                        David Mackenzie
# 96                        Justin Chadwick
# 97                     Guillermo del Toro
# 98                            Joss Whedon
# 99  Anthony Bell|Ben Gluck|Benjamin Gluck
#
#                                                Writer  \
# 0                      Mel Gibson|Benedict Fitzgerald
# 1   Peter Jackson|Philippa Boyens|Guillermo del To...
# 2                  John Logan|Robert Wade|Neal Purvis
# 3                           Jim Herzfeld|John Hamburg
# 4                                        Steve Kloves
# ..                                                ...
# 95                                    Taylor Sheridan
# ...

# %%
#Set a parameter to read the synopsis more in detail and applying a highlight function
df.style.set_properties(**{'background-color': 'linear-gradient(to bottom left, #9999ff 0%, #ff99cc 100%)',
                           'color': 'black'})
# Out:
# <style  type="text/css" >
#     #T_cb1ba6d8_7303_11ea_ab60_509a4cb82e96row0_col0 {
#             background-color:  linear-gradient(to bottom left, #9999ff 0%, #ff99cc 100%);
#             color:  black;
#         }    #T_cb1ba6d8_7303_11ea_ab60_509a4cb82e96row0_col1 {
#             background-color:  linear-gradient(to bottom left, #9999ff 0%, #ff99cc 100%);
#             color:  black;
#         }    #T_cb1ba6d8_7303_11ea_ab60_509a4cb82e96row0_col2 {
#             background-color:  linear-gradient(to bottom left, #9999ff 0%, #ff99cc 100%);
#             color:  black;
#         }    #T_cb1ba6d8_7303_11ea_ab60_509a4cb82e96row0_col3 {
#             background-color:  linear-gradient(to bottom left, #9999ff 0%, #ff99cc 100%);
#             color:  black;
#         }    #T_cb1ba6d8_7303_11ea_ab60_509a4cb82e96row0_col4 {
#             background-color:  linear-gradient(to bottom left, #9999ff 0%, #ff99cc 100%);
#             color:  black;
# ...

# %%
# Trimming the first 10 director to plot graph.
top10Director_df=df.head(10)
top10Director_df
# Out:
#            Director                                             Writer  \
# 0        Mel Gibson                     Mel Gibson|Benedict Fitzgerald
# 1     Peter Jackson  Peter Jackson|Philippa Boyens|Guillermo del To...
# 2        Sam Mendes                 John Logan|Robert Wade|Neal Purvis
# 3         Jay Roach                          Jim Herzfeld|John Hamburg
# 4    Chris Columbus                                       Steve Kloves
# 5        Joel Zwick                                       Nia Vardalos
# 6  Steven Spielberg                          Josh Friedman|David Koepp
# 7        Peter Berg     Vincent Gilligan|Vince Gilligan|Vy Vincent Ngo
# 8      Bryan Singer  Daniel Harris|Dan Harris|Michael Dougherty|Bry...
# 9        Justin Lin                                       Chris Morgan
#
#                                               Genre Rating  Theater_Date  \
# 0                                             Drama      R  Feb 25, 2004
# ...

# %%
# Plotting graph for the top 10 directors

plt.figure(figsize=(20,10),dpi=100)
plt.bar(top10Director_df['Director'],top10Director_df['Box_Office'],label='Top 10 Director',width=0.6)
plt.plot(top10Director_df['Director'],top10Director_df['Box_Office'],label='Top 10 Director'
         ,marker='o',markersize=12,markerfacecolor='Blue',ls='-.',color='grey',lw=5)
plt.style.use('fivethirtyeight')
plt.title("Recommended Directors for Movies")
plt.xlabel('Directors')
plt.ylabel('Revenue In Millions')
plt.legend(loc=1)
plt.tight_layout()
plt.show()

# %%
# Another format of plotting the top 10 Directors
plt.figure(figsize=(20,10),dpi=100)
plt.plot(top10Director_df['Director'],top10Director_df['Box_Office'],label='Top 10 Director'
         ,marker='o',markersize=12,markerfacecolor='Blue')
plt.style.use('fivethirtyeight')
plt.title("Recommended Directors for Movies")
plt.xlabel('Directors')
plt.ylabel('Revenue In Millions')
plt.legend(loc=1)
plt.tight_layout()
plt.show()

# %%
#Trimming values for the Top 20 studios to recommend
topstudios=df.head(20)

# %%
#PLotting a scatter plot to determine which studio is often used to make movies

plt.figure(figsize=(35,10))
plt.plot(topstudios['Studio'],topstudios['Box_Office'],
         label='Demand of Studio',ls='none', marker='*',markersize=20,markeredgecolor='red')
plt.style.use('fivethirtyeight')
plt.title("Recommended Studios",fontsize=30)
plt.xlabel('Studios',fontsize=30)
plt.ylabel('Revenue In Millions',fontsize=30)
plt.legend(loc=1)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##  "imdb.title.basics.csv.gz" Dataset

# %%
cd zippedData/
# Out:
# [WinError 2] The system cannot find the file specified: 'zippedData/'
# C:\Users\ssakb\zippedData

# %%
#Importing title basics dataset
df2=pd.read_csv("imdb.title.basics.csv.gz")
df2
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %%
#Print to check the details of the dataset
print(df.columns)
print(df.isnull().sum())
print(df.info())
# Out:
# Index(['Director', 'Writer', 'Genre', 'Rating', 'Theater_Date', 'Box_Office',
#        'Runtime', 'Studio', 'Synopsis'],
#       dtype='object')
# Director        0
# Writer          0
# Genre           0
# Rating          0
# Theater_Date    0
# Box_Office      0
# Runtime         0
# Studio          0
# Synopsis        0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
# Director        100 non-null object
# Writer          100 non-null object
# Genre           100 non-null object
# Rating          100 non-null object
# Theater_Date    100 non-null object
# Box_Office      100 non-null int64
# Runtime         100 non-null object
# Studio          100 non-null object
# Synopsis        100 non-null object
# dtypes: int64(1), object(8)
# memory usage: 7.2+ KB
# None

# %%
#Dropping all the null values by rows and columns
#Dropping 'tconst'column
#Renaming the primary title to later join to the movie table in another dataset
df2=df2.dropna().dropna(axis=1)
df2= df2.drop('tconst',axis=1)
df2= df2.rename(columns={'primary_title': 'movie'})
df2
# Out:
#                                                     movie  \
# 0                                               Sunghursh
# 1                         One Day Before the Rainy Season
# 2                              The Other Side of the Wind
# 4                                The Wandering Soap Opera
# 5                                             A Thin Life
# ...                                                   ...
# 146134                                         Drømmeland
# 146135                                      The Rehearsal
# 146136  Illenau - die Geschichte einer ehemaligen Heil...
# 146137                                          Safeguard
# 146139                                Kuambil Lagi Hatiku
#
#                                            original_title  start_year  \
# 0                                               Sunghursh        2013
# 1                                         Ashad Ka Ek Din        2019
# ...

# %% [markdown]
# ## "tn.movie_budgets.csv.gz" Dataset

# %%
cd zippedData/
# Out:
# [WinError 2] The system cannot find the file specified: 'zippedData/'
# C:\Users\ssakb\zippedData

# %%
#Imported movie budget dataset
movie_budgets=pd.read_csv("tn.movie_budgets.csv.gz")
movie_budgets
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# ...

# %%
# Replacing all the '$' and ',' with a basic integer value

movie_budgets['production_budget'] = movie_budgets['production_budget'].apply(lambda x: x.replace('$', '').replace(',', '')).astype('int64')
movie_budgets['domestic_gross'] = movie_budgets['domestic_gross'].apply(lambda x: x.replace('$', '').replace(',', '')).astype('int64')
movie_budgets['worldwide_gross'] = movie_budgets['worldwide_gross'].apply(lambda x: x.replace('$', '').replace(',', '')).astype('int64')

# %%
# Creating a new DataFrame to join the tables for later data analysis
# Added a new column NET PROFIT for easier analysis

new_moneybudgets=pd.DataFrame(movie_budgets['movie'])
new_moneybudgets['Movie_Budget']= movie_budgets['production_budget']
new_moneybudgets['National_Profit']=movie_budgets['domestic_gross']
new_moneybudgets['WorldWide_Profit']=movie_budgets['worldwide_gross']
new_moneybudgets['Net_Profit']=movie_budgets['worldwide_gross']-movie_budgets['production_budget']

# %% [markdown]
# ## Joining 2 Datasets "tn.movie_budgets.csv.gz" with "imdb.title.basics.csv.gz" Dataset

# %%
cc_df= pd.merge(new_moneybudgets,df2,how='inner',on="movie")
cc_df=cc_df.rename(columns={"start_year":"Year"})
cc_df
# Out:
#                                             movie  Movie_Budget  \
# 0                                          Avatar     425000000
# 1     Pirates of the Caribbean: On Stranger Tides     410600000
# 2                                    Dark Phoenix     350000000
# 3                         Avengers: Age of Ultron     330600000
# 4                          Avengers: Infinity War     300000000
# ...                                           ...           ...
# 3304                                        Clean         10000
# 3305                                         Cure         10000
# 3306                                    Newlyweds          9000
# 3307                                       Red 11          7000
# 3308                         A Plague So Pleasant          1400
#
#       National_Profit  WorldWide_Profit  Net_Profit  \
# 0           760507625        2776345279  2351345279
# 1           241063875        1045663875   635063875
# ...

# %%
# Sorting the columns to make sure the dataset is clean
# Rearranging the columns to for easy access
# Applying title method to all the column name
# Dropping all the duplicate values after joining

cc_df=cc_df.drop('original_title',axis=1)
cc_df=cc_df[['movie','genres','Movie_Budget','National_Profit','WorldWide_Profit','Net_Profit','Year','runtime_minutes']]
cc_df.columns = map(str.title, cc_df.columns)
cc_df.drop_duplicates(subset='Movie',keep="first")
cc_df
# Out:
#                                             Movie                    Genres  \
# 0                                          Avatar                    Horror
# 1     Pirates of the Caribbean: On Stranger Tides  Action,Adventure,Fantasy
# 2                                    Dark Phoenix   Action,Adventure,Sci-Fi
# 3                         Avengers: Age of Ultron   Action,Adventure,Sci-Fi
# 4                          Avengers: Infinity War   Action,Adventure,Sci-Fi
# ...                                           ...                       ...
# 3304                                        Clean       Comedy,Drama,Horror
# 3305                                         Cure                     Drama
# 3306                                    Newlyweds              Comedy,Drama
# 3307                                       Red 11    Horror,Sci-Fi,Thriller
# 3308                         A Plague So Pleasant     Drama,Horror,Thriller
#
# ...

# %%
# Arranging the Net Profit to later determine which movie makes most of the money
cc_df=cc_df.sort_values('Net_Profit',ascending=False).head(100)
cc_df
# Out:
#                        Movie                    Genres  Movie_Budget  \
# 0                     Avatar                    Horror     425000000
# 37                   Titanic                    Family     200000000
# 4     Avengers: Infinity War   Action,Adventure,Sci-Fi     300000000
# 25            Jurassic World   Action,Adventure,Sci-Fi     215000000
# 61                 Furious 7     Action,Crime,Thriller     190000000
# ...                      ...                       ...           ...
# 291               Life of Pi   Adventure,Drama,Fantasy     120000000
# 1448                   Ghost     Drama,Fantasy,Mystery      22000000
# 1449                   Ghost                    Horror      22000000
# 148     Thor: The Dark World  Action,Adventure,Fantasy     150000000
# 191     Ant-Man and the Wasp   Action,Adventure,Comedy     130000000
#
#       National_Profit  Worldwide_Profit  Net_Profit  Year  Runtime_Minutes
# ...

# %%
# Resetting the index column and counting a number of Genres
cc_df=cc_df.reset_index()
cc_df.drop('index',axis=1)
cc_df['Genres'].value_counts()
# Out:
# Action,Adventure,Sci-Fi          21
# Adventure,Animation,Comedy       14
# Action,Adventure,Fantasy          8
# Action,Adventure,Comedy           6
# Family,Fantasy,Musical            4
# Action,Crime,Thriller             3
# Horror                            3
# Adventure,Family,Fantasy          3
# Adventure,Fantasy                 2
# Adventure,Drama,Sci-Fi            2
# Adventure,Drama,Fantasy           2
# Drama,Fantasy,Romance             2
# Action,Adventure,Thriller         2
# Family                            2
# Action,Adventure,Animation        2
# Documentary                       2
# Biography,Drama,Music             1
# Biography,Documentary,History     1
# Fantasy,Musical                   1
# Drama,Sci-Fi,Thriller             1
# Adventure,Drama,Sport             1
# Fantasy,Romance                   1
# Animation                         1
# Action,Adventure,Drama            1
# Thriller                          1
# Horror,Thriller                   1
# ...

# %%
print(df.columns)
print(df.isnull().sum())
print(df.info())
# Out:
# Index(['Director', 'Writer', 'Genre', 'Rating', 'Theater_Date', 'Box_Office',
#        'Runtime', 'Studio', 'Synopsis'],
#       dtype='object')
# Director        0
# Writer          0
# Genre           0
# Rating          0
# Theater_Date    0
# Box_Office      0
# Runtime         0
# Studio          0
# Synopsis        0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
# Director        100 non-null object
# Writer          100 non-null object
# Genre           100 non-null object
# Rating          100 non-null object
# Theater_Date    100 non-null object
# Box_Office      100 non-null int64
# Runtime         100 non-null object
# Studio          100 non-null object
# Synopsis        100 non-null object
# dtypes: int64(1), object(8)
# memory usage: 7.2+ KB
# None

# %%
# Defining a function to count an individual genre in the dataset

def counter(df,col):
    genre_dict={}
    for genres in df[col]:
        for genre in genres.split(","):
            if genre in genre_dict:
                genre_dict[genre]+=1
            else:
                genre_dict[genre]=1
    return genre_dict

# %%
totalcount=counter(cc_df,'Genres')
print(totalcount)
# Out:
# {'Horror': 4, 'Family': 12, 'Action': 46, 'Adventure': 66, 'Sci-Fi': 26, 'Crime': 4, 'Thriller': 11, 'Drama': 15, 'Sport': 2, 'Animation': 18, 'Comedy': 23, 'Fantasy': 25, 'Romance': 4, 'Musical': 5, 'Biography': 2, 'Music': 1, 'Documentary': 4, 'History': 1, 'Mystery': 2}

# %%
# Converting the dictionaries int0 a list to  plot a graph and count the number of movies in particular genre
x=list(totalcount.keys())
y=list(totalcount.values())

# %%
# Plotting a graph in relation to the number of movies with the respected genres

plt.figure(figsize=(25,10),dpi=100)
plt.style.use('fivethirtyeight')
plt.bar(x,y,label='Different Genres',color='#556b2f')
plt.plot(x,y,label='Number of Movies',color='#0000A0')
plt.title("Genre of Top 100 movies", fontsize=25)
plt.xlabel('Genres',fontsize=35)
plt.ylabel('Number of movies',fontsize=35)
plt.legend(loc=1)
plt.show()

# %%
# finding an average to invest in the movie industry
MeanMB = cc_df.mean()
MeanMB
df_moviebudget_mean = cc_df.groupby('Genres')['Movie_Budget'].mean()
fig = df_moviebudget_mean.plot(kind='bar',figsize=(32,13),title="Average Cost Production of Movies",legend="Cost",xticks=(range(0,8)),rot=65,color='y')

# %%
df_moviebudget_mean
# Out:
# Genres
# Action,Adventure,Animation       1.750000e+08
# Action,Adventure,Comedy          1.230000e+08
# Action,Adventure,Drama           1.700000e+08
# Action,Adventure,Family          1.800000e+08
# Action,Adventure,Fantasy         2.113250e+08
# Action,Adventure,Sci-Fi          1.966952e+08
# Action,Adventure,Thriller        2.500000e+08
# Action,Crime,Thriller            1.883333e+08
# Action,Sci-Fi,Thriller           1.160000e+08
# Action,Thriller                  2.750000e+08
# Adventure,Animation,Comedy       1.396429e+08
# Adventure,Drama,Family           1.750000e+08
# Adventure,Drama,Fantasy          9.400000e+07
# Adventure,Drama,Sci-Fi           1.365000e+08
# Adventure,Drama,Sport            1.500000e+08
# Adventure,Family,Fantasy         2.100000e+08
# Adventure,Fantasy                2.500000e+08
# Animation                        1.750000e+08
# Animation,Comedy,Family          7.500000e+07
# Biography,Documentary,History    1.750000e+08
# ...

# %%
# Returning the result with average revenue from Nationwide

df_nationalprofit_mean=cc_df.groupby('Genres')['National_Profit'].mean()
df_nationalprofit_mean
fig = df_nationalprofit_mean.plot(kind='line',figsize=(32,13),title="Average National Profit from Movies",legend="Profit Margin",color='g')

# %%
df_nationalprofit_mean
# Out:
# Genres
# Action,Adventure,Animation       3.869154e+08
# Action,Adventure,Comedy          3.261751e+08
# Action,Adventure,Drama           2.085456e+08
# Action,Adventure,Family          2.414073e+08
# Action,Adventure,Fantasy         2.819640e+08
# Action,Adventure,Sci-Fi          4.123764e+08
# Action,Adventure,Thriller        2.522172e+08
# Action,Crime,Thriller            2.629344e+08
# Action,Sci-Fi,Thriller           2.135114e+08
# Action,Thriller                  4.481391e+08
# Adventure,Animation,Comedy       3.165395e+08
# Adventure,Drama,Family           3.640011e+08
# Adventure,Drama,Fantasy          2.127594e+08
# Adventure,Drama,Sci-Fi           2.082258e+08
# Adventure,Drama,Sport            4.007380e+08
# Adventure,Family,Fantasy         2.904108e+08
# Adventure,Fantasy                2.567433e+08
# Animation                        3.640011e+08
# Animation,Comedy,Family          2.703290e+08
# Biography,Documentary,History    3.564617e+08
# ...

# %%
# Returning a result of the average revenue from movie industry

df_worldprofit_mean=cc_df.groupby('Genres')['Worldwide_Profit'].mean()
df_worldprofit_mean
fig = df_worldprofit_mean.plot(kind='barh',figsize=(25,15),title="Average Worldwide Profit from Movies",legend="Profit")

# %%
df_worldprofit_mean
# Out:
# Genres
# Action,Adventure,Animation       9.536791e+08
# Action,Adventure,Comedy          7.988658e+08
# Action,Adventure,Drama           7.106446e+08
# Action,Adventure,Family          7.585367e+08
# Action,Adventure,Fantasy         8.420625e+08
# Action,Adventure,Sci-Fi          1.094364e+09
# Action,Adventure,Thriller        9.950740e+08
# Action,Crime,Thriller            1.127911e+09
# Action,Sci-Fi,Thriller           8.536286e+08
# Action,Thriller                  1.084439e+09
# Adventure,Animation,Comedy       9.441278e+08
# Adventure,Drama,Family           9.628545e+08
# Adventure,Drama,Fantasy          6.635074e+08
# Adventure,Drama,Sci-Fi           6.608254e+08
# Adventure,Drama,Sport            1.272470e+09
# Adventure,Family,Fantasy         9.482992e+08
# Adventure,Fantasy                9.529722e+08
# Animation                        9.628545e+08
# Animation,Comedy,Family          6.344548e+08
# Biography,Documentary,History    8.542360e+08
# ...
